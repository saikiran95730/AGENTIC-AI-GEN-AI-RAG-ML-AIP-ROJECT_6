# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %%
import sys
sys.version # Get operating system version
# Out:
# '3.14.6 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:30:20) [Clang 20.1.8 ]'

# %%
import keyword
keyword.iskeyword("for") # Check whether 'for' is reserved keyword or not
# Out:
# True

# %%
import operator
operator.add(20, 20) # Add 20*20
# Out:
# 40

# %%
operator.mul(90, 20) # Multiply 90*20
# Out:
# 1800

# %%
operator.sub(20, 20) # Substarct 20-20
# Out:
# 0

# %%
from datetime import datetime
datetime.now() # Get current date and time
# Out:
# datetime.datetime(2026, 8, 25, 18, 16, 21, 561619)

# %%
from datetime import datetime
datetime.today() # Get today date and time
# Out:
# datetime.datetime(2026, 8, 25, 18, 16, 44, 610166)

# %%
import os
os.getcwd() # Get current working directory like files, folders, paths
# Out:
# '/Users/potharlasaikiran'

# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %% [markdown]
# ## Keywords

# %% [markdown]
# Keywords are the reserved words in Python and can't be used as an identifier i.e., variables, functions,

# %%
print(keyword.kwlist) # Lists all python Keywords
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# ## Identifiers

# %% [markdown]
# An identifier is a name given to entities like class, functions, variables, etc. It helps to differentiate one entity from another.

# %%
1var = 10 # Identifier can't start with a number
# Out:
#   Cell In[15], line 1
#     1var = 0
#     ^
# SyntaxError: invalid decimal literal

# %%
var1 = 10 # but can end with number

# %%
var@ = 10 # special characters can't be used in identifiers
# Out:
#   Cell In[17], line 1
#     var@ = 10 # special characters can't be used in identifiers
#          ^
# SyntaxError: invalid syntax

# %%
var# = 10 # special characters can't be used in identifiers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 var# = 10 # special characters can't be used in identifiers
#
# NameError: name 'var' is not defined

# %%
var_ = 10 # only '_' (undescore) can be used in an identifier

# %%
import = 125
# Out:
#   Cell In[20], line 1
#     import = 125
#            ^
# SyntaxError: invalid syntax

# %%
p = 10
q = 20
r = q
p, type(p), hex(id(p))
# Out:
# (10, int, '0x1047b2680')

# %%
id(p), id(r)
# Out:
# (4370146944, 4370147264)

# %%
id(p), id(q), id(r)
# Out:
# (4370146944, 4370147264, 4370147264)

# %%
intvar = 20
floatvar = 20.29
strvar = "Python prog"
print(intvar), print(type(intvar))
print(floatvar), print(type(floatvar))
print(strvar), print(type(strvar))
# Out:
# 20
# <class 'int'>
# 20.29
# <class 'float'>
# Python prog
# <class 'str'>
# (None, None)

# %%
p1 = p2 = p3 = p4 = 45
print(p1, p2, p3, p4)
# Out:
# 45 45 45 45

# %%
x = "Hello"
id(x)
# Out:
# 4438696144

# %%
hex(id(x))
# Out:
# '0x1089120d0'

# %% [markdown]
# # Numeric

# %%
val1 = 20
print(val1)
isinstance(val1, int)
# Out:
# 20
# True

# %%
val1 = 20
print(val1)
isinstance(val1, str)
print(sys.getsizeof(val1))
# Out:
# 20
# 28

# %%
val2 = 10 + 20j
print(type(val2))
isinstance(val2, complex)
# Out:
# <class 'complex'>
# True

# %%
print(val2)
# Out:
# (10+20j)

# %% [markdown]
# # Boolean

# %%
b1 = True
b2 = False
print(type(b1))
# Out:
# <class 'bool'>

# %%
print(type(b2))
# Out:
# <class 'bool'>

# %%
isinstance(b1, bool)
# Out:
# True

# %%
isinstance(b2, bool)
# Out:
# True

# %%
isinstance(b1, str)
# Out:
# False

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %% [markdown]
# # String

# %%
mystring = 'Hello String'
mystring
# Out:
# 'Hello String'

# %%
str1 = 'Hello Sai' # Define string using single quotes
str1
# Out:
# 'Hello Sai'

# %%
str2 = "Hello Sai" # Define string using doublr quotes
str2
# Out:
# 'Hello Sai'

# %%
str3 = '''Hello 
          World''' # Define string using triple quotes
str3
# Out:
# 'Hello \n          World'

# %%
print(str3)
# Out:
# Hello
#           World

# %%
str4 = """Hello 
          World"""
str4
# Out:
# 'Hello \n          World'

# %%
print(str4)
# Out:
# Hello
#           World

# %%
str5 = ( 'Happy ' 
         'Birthday '
         'to me ' )
print(str5)
# Out:
# Happy Birthday to me

# %%
mystr1 = "SAI"
mystr1 = mystr1*5
mystr1
# Out:
# 'SAISAISAISAISAI'

# %%
len(mystr1)
# Out:
# 15

# %% [markdown]
# # String Indexing

# %%
str1
# Out:
# 'Hello Sai'

# %%
str1(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 str1(0)
#
# TypeError: 'str' object is not callable

# %%
str1[0] # Only [] should be used for indexing
# Out:
# 'H'

# %%
str1[7]
# Out:
# 'a'

# %%
str1[1:]
# Out:
# 'ello Sai'

# %%
str1[:1]
# Out:
# 'H'

# %%
len(str1)
# Out:
# 9

# %%
str1[len(str1) - 1]
# Out:
# 'i'

# %%
str1[:9]
# Out:
# 'Hello Sai'

# %%
str1[9:]
# Out:
# ''

# %% [markdown]
# # String Slicing

# %%
str1[:]
# Out:
# 'Hello Sai'

# %%
str1[2:7]
# Out:
# 'llo S'

# %%
str1[0:8]
# Out:
# 'Hello Sa'

# %%
str1[2:9]
# Out:
# 'llo Sai'

# %%
str1[-8]
# Out:
# 'e'

# %% [markdown]
# String has 2 indes
# 1. forward index-- starts with 0
# 2. Bacward indes-- starts with -1
#    For example take si = 'HELLO PYTHON' then
#
# 1. forward index   :______0_____1_____2____3____4_____5_____6_____7_____8
#
#                si = '   H    e    l    l    o         S    a    i   '
#
# 4. backward index:........-9.......-8.......-7.......-6.......-5.......-4.......-3.......-2.......-1

# %%
str1[5:-1]
# Out:
# ' Sa'

# %% [markdown]
# # Update & Delete String

# %%
str1
# Out:
# 'Hello Sai'

# %%
del str1 # Delete a string
print(str1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 del str1
#       2 print(str1)
#
# NameError: name 'str1' is not defined

# %%
str1 = 'HEllO SAI'
str1
# Out:
# 'HEllO SAI'

# %%
str1[0:5] = 'HOLLA"
# Out:
#   Cell In[76], line 1
#     str1[0:5] = 'HOLLA"
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# # String concatenation

# %%
s1 = 'Hello '
s2 = 'Sai'
s3 = s1 + s2
s3
# Out:
# 'Hello Sai'
