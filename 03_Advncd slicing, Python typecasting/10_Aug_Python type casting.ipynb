# %% [markdown]
# # Python type casting

# %% [markdown]
# ### Checking whether converting all datatypes to inetegers is possible or not

# %%
115.98
# Out:
# 115.98

# %%
int(115.98) # Float to Interger is possible
# Out:
# 115

# %%
int(True) # Boolean to Integer is possible
# Out:
# 1

# %%
int(10+20j) # Complex to Integer is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(10+20j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int("10") # Number string to integer is possible but whereas below
# Out:
# 10

# %%
int("Ten") # Text string to integer is not possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int("Ten") # Tet string to integer is not possible
#
# ValueError: invalid literal for int() with base 10: 'Ten'

# %% [markdown]
# * in type casting, while typecast or converting all datatypes to integers is possible except complex and text string

# %% [markdown]
# ### Other datatype to float

# %%
110
# Out:
# 110

# %%
float(110) # Integers to Float is possible
# Out:
# 110.0

# %%
float(False) # Boolean to Float is possibke
# Out:
# 0.0

# %%
float(True)
# Out:
# 1.0

# %%
float(10+20J) # Complex to Float is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 float(10+20J) # Complex to Float is
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float("10") # Number String to Float is Possible
# Out:
# 10.0

# %%
float("Ten") # String to Float is not possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 float("Ten") # String to Float is
#
# ValueError: could not convert string to float: 'Ten'

# %% [markdown]
# * in type casting, while typecast or converting all datatypes to Float is possible except complex and text string

# %% [markdown]
# ### Other datatype to Boolean

# %%
110
# Out:
# 110

# %%
bool(110) # Integer is boolean is possible
# Out:
# True

# %%
bool(0) # Integer to boolean is possible
# Out:
# False

# %%
bool(110.98) # Float to boolean is possible
# Out:
# True

# %%
bool(10+20j) # Complex to boolean is possible
# Out:
# True

# %%
bool("10") # Number string to boolean is possible
# Out:
# True

# %%
bool("Ten") # String to boolean is possible
# Out:
# True

# %%
bool( )
# Out:
# False

# %% [markdown]
# * in type casting, while typecast or converting all datatypes to Boolean is possible

# %% [markdown]
# ### Other datatype to Complex

# %%
complex(2, 3, 5) # complex should have only 2 argumwnts but given here are 3, so its not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 complex(2, 3, 5) # complex should have only 2 argumwnts but given here are 3, so its not possible
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex(2, 3) # Integer to Complex is possible
# Out:
# (2+3j)

# %%
complex(74.74)
# Out:
# (74.74+0j)

# %%
complex(220.98, 76.98) # Float to Complex is possible
# Out:
# (220.98+76.98j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False) # Boolean to Complex is possible
# Out:
# 0j

# %%
complex('10') # Number String to Complex is possible
# Out:
# (10+0j)

# %%
complex('Ten') # Text String to Complex is possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 complex('Ten') # String to Complex is possible
#
# ValueError: complex() arg is a malformed string

# %%
complex('10', '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 complex('10', '20')
#
# TypeError: complex() argument 'real' must be a real number, not str

# %%
complex(10, '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 complex(10, '20')
#
# TypeError: complex() argument 'imag' must be a real number, not str

# %% [markdown]
# * in type casting, while typecast or converting all datatypes to Complex is possible except string because only 1 text string is valid

# %% [markdown]
# ### Other datatype to String

# %%
str(10) # Integer to String is possible
# Out:
# '10'

# %%
str(10.24) # Float to String is possible
# Out:
# '10.24'

# %%
str(True) # Boolean to String is possible
# Out:
# 'True'

# %%
str(10+20j) # Complex to String is possible
# Out:
# '(10+20j)'

# %% [markdown]
# * in type casting, all other types to String is possible
